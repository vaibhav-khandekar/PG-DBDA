# %% [markdown]
# # Pandas

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('/content/weather_data1.csv')
df
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017           35          7  Sunny
# 2  1/3/2017           28          2   Snow
# 3  1/4/2017           24          7   Snow
# 4  1/5/2017           32          4   Rain
# 5  1/6/2017           31          2  Sunny

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   day          6 non-null      object
#  1   temperature  6 non-null      int64
#  2   windspeed    6 non-null      int64
#  3   event        6 non-null      object
# dtypes: int64(2), object(2)
# memory usage: 320.0+ bytes

# %%
#print first five rows of data
df.head()
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017           35          7  Sunny
# 2  1/3/2017           28          2   Snow
# 3  1/4/2017           24          7   Snow
# 4  1/5/2017           32          4   Rain

# %%
#print last five rows of data
df.tail()
# Out:
#         day  temperature  windspeed  event
# 1  1/2/2017           35          7  Sunny
# 2  1/3/2017           28          2   Snow
# 3  1/4/2017           24          7   Snow
# 4  1/5/2017           32          4   Rain
# 5  1/6/2017           31          2  Sunny

# %%
#it will print the column names of the data
df.columns
# Out:
# Index(['day', 'temperature', 'windspeed', 'event'], dtype='object')

# %%
#print first 3 records by using index
df[1:4]
# Out:
#         day  temperature  windspeed  event
# 1  1/2/2017           35          7  Sunny
# 2  1/3/2017           28          2   Snow
# 3  1/4/2017           24          7   Snow

# %%
#it will print particular columns with certain information
df['day']
# Out:
# 0    1/1/2017
# 1    1/2/2017
# 2    1/3/2017
# 3    1/4/2017
# 4    1/5/2017
# 5    1/6/2017
# Name: day, dtype: object

# %%
#it will print type of dataframe respect to column
type(df['day'])
# Out:
# pandas.core.series.Series

# %%
#it will print 2 mentoined columns
df[['day','temperature']]
# Out:
#         day  temperature
# 0  1/1/2017           32
# 1  1/2/2017           35
# 2  1/3/2017           28
# 3  1/4/2017           24
# 4  1/5/2017           32
# 5  1/6/2017           31

# %%
#maximum temperature
max(df.temperature)
# Out:
# 35

# %%
#checking if there are any records having temperature more than 35
df[df['temperature'] > 35]
# Out:
# Empty DataFrame
# Columns: [day, temperature, windspeed, event]
# Index: []

# %%
df[df['temperature'] > 32]
# Out:
#         day  temperature  windspeed  event
# 1  1/2/2017           35          7  Sunny

# %%
df[['day','temperature']] [df['temperature'] > 32]
# Out:
#         day  temperature
# 1  1/2/2017           35

# %%
df[['day']] == [df['temperature'].max()]
# Out:
#      day
# 0  False
# 1  False
# 2  False
# 3  False
# 4  False
# 5  False

# %%
df['temperature'].std()
# Out:
# 3.8297084310253524

# %%
df = df.replace(35,40)
df
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017           40          7  Sunny
# 2  1/3/2017           28          2   Snow
# 3  1/4/2017           24          7   Snow
# 4  1/5/2017           32          4   Rain
# 5  1/6/2017           31          2  Sunny

# %% [markdown]
# #homework -> replacement

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
x = np.arange(0,10)
y = np.arange(11,21)

# %%
plt.scatter(x,y,c='violet')

# %%
plt.scatter(x,y,c='orange')
plt.xlabel('X axis')
plt.ylabel('Y axis')
plt.title('Graph in 2 dimension')
# Out:
# Text(0.5, 1.0, 'Graph in 2 dimension')

# %%
plt.scatter(x,y,c='red')
plt.xlabel('X axis')
plt.ylabel('Y axis')
plt.title('Graph in 2 dimension')
# Out:
# Text(0.5, 1.0, 'Graph in 2 dimension')

# %%
plt.plot(x,y,marker = '*', c='pink')
plt.xlabel('X axis')
plt.ylabel('Y axis')
plt.title('Graph in 2 dimension')
# Out:
# Text(0.5, 1.0, 'Graph in 2 dimension')

# %%
plt.plot(x,y,'r*',)
plt.xlabel('X axis')
plt.ylabel('Y axis')
plt.title('Graph in 2 dimension')

# %%
plt.plot(x*x,y)
plt.xlabel('X axis')
plt.ylabel('Y axis')
plt.title('Graph in 2 dimension')
# Out:
# Text(0.5, 1.0, 'Graph in 2 dimension')

# %%
x = np.arange(1,11)
y = 3*x+5
plt.plot(x,y)

# %%
x = np.arange(1,4*np.pi,0.1)
y = np.sin(x)

# %%
plt.plot(x,y,c = 'brown')

# %%
df1 = pd.read_csv('/content/tips.csv')

# %%
df1.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
import seaborn as sb

# %%
sb.load_dataset("tips")
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
df1.corr()
# Out:
# <ipython-input-66-49b3fcfeb4d1>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df1.corr()
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
sb.heatmap(df1.corr())
# Out:
# <ipython-input-67-86102e67b8e1>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sb.heatmap(df1.corr())
# <Axes: >

# %%
sb.jointplot(df1.corr())
# Out:
# <ipython-input-68-2158d94313af>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sb.jointplot(df1.corr())
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-68-2158d94313af> in <cell line: 1>()
# ----> 1 sb.jointplot(df1.corr())
#
# /usr/local/lib/python3.10/dist-packages/seaborn/axisgrid.py in jointplot(data, x, y, hue, kind, height, ratio, space, dropna, xlim, ylim, color, palette, hue_order, hue_norm, marginal_ticks, joint_kws, marginal_kws, **kwargs)
#    2263
#    2264         marginal_kws.setdefault("color", color)
# -> 2265         grid.plot_marginals(marg_func, **marginal_kws)
#    2266
#    2267     elif kind.startswith("hist"):
#
# ...

# %%
sb.jointplot(x = 'tip',y = 'total_bill',data = df1)

# %%
sb.pairplot(df1)

# %%
sb.pairplot(df1, hue = 'sex')

# %%
sb.distplot(df1['tip'])
# Out:
# <ipython-input-73-54bb597f39fb>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sb.distplot(df1['tip'])
# <Axes: xlabel='tip', ylabel='Density'>

# %% [markdown]
# # Homework
# barchart, boxplot, piechart on categorical data

# %% [markdown]
# # Categorical Plots

# %%
#countplot
sb.countplot(x = df1['sex']) #method 1
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %%
sb.countplot(x = 'sex',data = df1) #method 2
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %%
#boxplot
sb.boxplot(x = 'smoker',y = 'total_bill',data = df1)
# Out:
# <Axes: xlabel='smoker', ylabel='total_bill'>

# %% [markdown]
# # Outliers / Anomaly
#
# - out of range
# - anomalies are those values which are not in range.
# - there are two types of outliers.
# - Minimum -> Q1 - 1.5*IQR
# - Maximum -> Q3 + 1.5*IQR

# %%
#boxplot
sb.boxplot(x = 'day',y = 'total_bill',data = df1)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
#boxplot
sb.boxplot(x = 'day',y = 'total_bill',data = df1,palette = 'rainbow')
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
#boxplot
sb.boxplot(x = 'day',y = 'total_bill',data = df1,orient = 'v')
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
#boxplot
sb.boxplot(x = 'day',y = 'total_bill',data = df1,palette = 'rainbow')

# %%
#boxplot
sb.violinplot(x = 'day',y = 'total_bill',data = df1,palette = 'rainbow')
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
#boxplot
sb.violinplot(y = 'day',x = 'total_bill',data = df1,palette = 'rainbow')
# Out:
# <Axes: xlabel='total_bill', ylabel='day'>

# %% [markdown]
# # Homework
#  - Analyse the iris dataset with diffrent plots.
