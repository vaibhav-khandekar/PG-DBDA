# %%
#create a bank class 
# has amount,accountno,name
# createaccount(constructor)-user only gives name and amount 
# account number auto generated
#withdraw(amount):should not be -ve amount and min 
# balance is 2000 else reject transection
#deposite(amount):amount can not be -ve
#checkbalance():shows balance and account holder name

'''
menu driven code to 
1 create account
2 withdraw
3 deposit
4 check balance
5 exit
1---->create by takingvalues and auto generate account number
2/3/4--->ask account number ,search account and then operate'''


class Bank():
    acc_no=202300
    def __init__(self,name,balance):
        Bank.acc_no+=1
        self.__acc_no=Bank.acc_no
        self.__name=name
        self.__balance=balance
    def __str__(self):
        return "account no = "+str(self.__acc_no)+" name = "+self.__name+" amount = "+str(self.__balance)
    def getacc_no(self):
        return self.__acc_no
    def withdraw(self,balance):
        self.__balance-=balance
    def deposit(self,balance):
        self.__balance+=balance
    def getbalance(self):
        return self.__balance

# %%
l=[]
while True:
    print("1.Create\n2.Withdraw\n3.Deposit\n4.Checkbalance\n5.Print all details\n6.Exit")
    ch=int(input(":"))
    if ch==1:
        n=input("enter account holder name = ")
        a=float(input("account opening balance = "))
        b=Bank(n,a)
        l.append(b)
        print(b)
    #withdraw
    elif ch==2:
        an=int(input('enter account number = '))
        flag=False
        for i in l:
            if i.getacc_no()==an:
                print('account found')
                flag=True
                print(i)
                if i.getbalance()>=2000:
                    am=float(input('enter amount to withdraw = '))
                    if am>0:
                        i.withdraw(am)
                        print("money withdrawal",i)
                    else:
                        print('please enter valid amount to enter')
                else:
                    print("you have reach your min limit, so you are not able to withdraw")
                break
        if flag==False:
            print('account not found')
    #deposit
    elif ch==3:
        an=int(input('enter account number = '))
        flag=False
        for i in l:
            if i.getacc_no()==an:
                print('account found')
                flag=True
                print(i)
                am=float(input('enter amount to deposit = '))
                if am>0:
                    i.deposit(am)
                    print("money deposited",i)
                    break
                else:
                    print('please enter valid amount')
        if flag==False:
            print('not found')
    #checkbalance
    elif ch==4:
        an=int(input('enter account number = '))
        flag=False
        for i in l:
            if i.getacc_no()==an:
                print('account found')
                flag=True
                print(i)
        if flag==False:
            print('not found')
    #print all account details
    elif ch==5:
        if len(l)==0:
            print("empty list")
        else:
            for i in l:
                print(i)                
    #break
    elif ch==6:
        print("bye")
        break
    else:
        print("please enter valid choice")
# Out:
# 1.Create
# 2.Withdraw
# 3.Deposit
# 4.Checkbalance
# 5.Print all details
# 6.Exit
# :1
# enter account holder name = wqw
# account opening balance = 4000
# account no = 202301 name = wqw amount = 4000.0
# 1.Create
# 2.Withdraw
# 3.Deposit
# 4.Checkbalance
# 5.Print all details
# 6.Exit
# :2
# enter account number = 202301
# account found
# account no = 202301 name = wqw amount = 4000.0
# enter amount to withdraw = 3000
# money withdrawal account no = 202301 name = wqw amount = 1000.0
# 1.Create
# 2.Withdraw
# 3.Deposit
# 4.Checkbalance
# 5.Print all details
# 6.Exit

# %% [markdown]
# Product: This class represents a product that is sold on the website and has the following attributes: product_id, product_name, product_description, product_price, and product_quantity. It also has methods to update the product quantity and view product details.
#
# Cart: This class represents a user's shopping cart and has the following attributes: cart_id, user_id, and products. It also has methods to add products to the cart, remove products from the cart, and view the cart.
#
# Order: This class represents an order that is placed by a user and has the following attributes: order_id, user_id, order_date, order_total, and order_items. It also has methods to add items to the order and view the order details.
#
# User: This class represents a user who has registered on the website and has the following attributes: user_id, user_name, user_email, and user_password. It also has methods to register, login, and view the user details.

# %%
class Website:
    def __init__
