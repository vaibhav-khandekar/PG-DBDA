# %% [markdown]
# # Set
#
# - Sets are used to store multiple values in a single variable.
# - Set is one of 4 built-in data types in Python used to store collections of data.
# - A set is a collection of data which is unordered, unchangeable and unindexed.
# - Set items are unchangeable, but you can remove items and add new items.
# - Sets are denoted by curly brackets.

# %%
thisset = {'meteor','gt650','classic'}
thisset
# Out:
# {'classic', 'gt650', 'meteor'}

# %% [markdown]
# ## Unorderd
#
# - Sets are unordered, so you cannot be sure in which order in which order the items will appear.
# - In other words set do not have a defined order.
# - Set items can appear in a different order every time you use them, and cannot be reffered to by index or key.

# %%
thisset
# Out:
# {'classic', 'gt650', 'meteor'}

# %% [markdown]
# ## Unchangeable
#
# - Set items are unchangeable means that we cannot change the items after the set has been created.
# - Once set is created, you cannot change its items, but you can remove items and add new items.

# %% [markdown]
# ## Duplicates Not Allowed
#
# - Sets cannot have two items with the same value.
# - Duplicate values will not print in the set.

# %%
thisset = {'meteor350','meteor650','gt650','interceptor650','classic350','meteor650'}
thisset
# Out:
# {'classic350', 'gt650', 'interceptor650', 'meteor350', 'meteor650'}

# %% [markdown]
# ## **NOTE**
#
# - The values True and 1 are considered as the same values in sets and treated as duplicates.

# %%
new_set = {'vaibhav',True,1,2}
new_set
# Out:
# {2, True, 'vaibhav'}

# %% [markdown]
# ## Length of Set
#
# - To determine how many items a set has, use len() function.

# %%
len(thisset)
# Out:
# 5

# %% [markdown]
# ## Set Items - Data Types
#
# - Set items can be of any data type.

# %%
set1 = {'vaibhav','dbda',True,73}
set1
# Out:
# {73, True, 'dbda', 'vaibhav'}

# %% [markdown]
# ## Type()
#
# - From Python's perspective, sets are defined as objects with the data type 'set'.

# %%
print(type(set1))
# Out:
# <class 'set'>

# %% [markdown]
# ## The set() Constructor
#
# - It is also possible to use set() constructor to make it.

# %%
new_set = set(('CDAC_DBDA',True,73))
new_set
# Out:
# {73, 'CDAC_DBDA', True}
